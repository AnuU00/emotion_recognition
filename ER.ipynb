# %%
import cv2
from deepface import DeepFace

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")
    
while True:
    ret,frame = cap.read()
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.1, 4)
    
    for(x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    cv2.putText(frame,
                result[0]['dominant_emotion'],
                (50, 50),
                font, 3,
                (0, 0, 255),
                2,
                cv2.LINE_4)
    cv2.imshow('Demo video', frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
    cap.release()
    cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:From F:\anaconda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 14
#      12 while True:
#      13     ret,frame = cap.read()
# ---> 14     result = DeepFace.analyze(frame, actions = ['emotion'])
#      16     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      17     faces = faceCascade.detectMultiScale(gray, 1.1, 4)
#
# File F:\anaconda\Lib\site-packages\deepface\DeepFace.py:335, in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     332 # ---------------------------------
#     333 resp_objects = []
# --> 335 img_objs = functions.extract_faces(
#     336     img=img_path,
#     337     target_size=(224, 224),
#     338     detector_backend=detector_backend,
#     339     grayscale=False,
#     340     enforce_detection=enforce_detection,
#     341     align=align,
#     342 )
#     344 for img_content, img_region, img_confidence in img_objs:
#     345     if img_content.shape[0] > 0 and img_content.shape[1] > 0:
#
# File F:\anaconda\Lib\site-packages\deepface\commons\functions.py:160, in extract_faces(img, target_size, detector_backend, grayscale, enforce_detection, align)
#     157 extracted_faces = []
#     159 # img might be path, base64 or numpy array. Convert it to numpy whatever it is.
# --> 160 img, img_name = load_image(img)
#     161 img_region = [0, 0, img.shape[1], img.shape[0]]
#     163 if detector_backend == "skip":
#
# File F:\anaconda\Lib\site-packages\deepface\commons\functions.py:98, in load_image(img)
#      95     return img, None
#      97 # The image is a base64 string
# ---> 98 if img.startswith("data:image/"):
#      99     return loadBase64Img(img), None
#     101 # The image is a url
#
# AttributeError: 'NoneType' object has no attribute 'startswith'

# %%
import cv2
from deepface import DeepFace

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")
    
while True:
    ret,frame = cap.read()
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.1, 4)
    
    for(x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    cv2.putText(frame,
                result[0]['dominant_emotion'],
                (50, 50),
                font, 3,
                (0, 0, 255),
                2,
                cv2.LINE_4)
    cv2.imshow('Demo video', frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
    cap.release()
    cv2.destroyAllWindows()

# %%
import cv2
from deepface import DeepFace

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")

while True:
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break

    result = DeepFace.analyze(frame, actions = ['emotion'])

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.1, 4)

    for(x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    font = cv2.FONT_HERSHEY_SIMPLEX

    cv2.putText(frame,
                result[0]['dominant_emotion'],
                (50, 50),
                font, 3,
                (0, 0, 255),
                2,
                cv2.LINE_4)
    cv2.imshow('Live Camera', frame)

    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
from deepface import DeepFace

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture('emotionVideo.mp4')
if not cap.isOpened():
    raise IOError("Cannot open video file")

while True:
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break

    result = DeepFace.analyze(frame, actions = ['emotion'])

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.1, 4)

    for(x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    font = cv2.FONT_HERSHEY_SIMPLEX

    cv2.putText(frame,
                result[0]['dominant_emotion'],
                (0, 50),
                font, 3,
                (0, 0, 255),
                2,
                cv2.LINE_4)
    cv2.imshow('Video File', frame)

    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 16
#      13     print("Can't receive frame (stream end?). Exiting ...")
#      14     break
# ---> 16 result = DeepFace.analyze(frame, actions = ['emotion'])
#      18 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      19 faces = faceCascade.detectMultiScale(gray, 1.1, 4)
#
# File F:\anaconda\Lib\site-packages\deepface\DeepFace.py:335, in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     332 # ---------------------------------
#     333 resp_objects = []
# --> 335 img_objs = functions.extract_faces(
#     336     img=img_path,
#     337     target_size=(224, 224),
#     338     detector_backend=detector_backend,
#     339     grayscale=False,
#     340     enforce_detection=enforce_detection,
#     341     align=align,
#     342 )
#     344 for img_content, img_region, img_confidence in img_objs:
#     345     if img_content.shape[0] > 0 and img_content.shape[1] > 0:
#
# File F:\anaconda\Lib\site-packages\deepface\commons\functions.py:178, in extract_faces(img, target_size, detector_backend, grayscale, enforce_detection, align)
#     172         raise ValueError(
#     173             f"Face could not be detected in {img_name}."
#     174             "Please confirm that the picture is a face photo "
#     175             "or consider to set enforce_detection param to False."
#     176         )
#     177     else:
# --> 178         raise ValueError(
#     179             "Face could not be detected. Please confirm that the picture is a face photo "
#     180             "or consider to set enforce_detection param to False."
#     181         )
#     183 if len(face_objs) == 0 and enforce_detection is False:
#     184     face_objs = [(img, img_region, 0)]
#
# ValueError: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
